# %% [markdown]
# by: **Christian Mantilla**
# LinkedIn: https://www.linkedin.com/in/cmanti/
# github: https://github.com/chris14jan

# %% [markdown]
# # Scope

# %% [markdown]
# **- CFC Insight Technical Challenge**
# This technical challenge is designed to take up to 2 hours.
# Your submission should be uploaded to a github repository and include your python
# code, a requirements.txt file and any setup or running instructions.
# All code should be written for python version >=3.6. You are allowed to use external
# libraries and binaries if you choose.
#
# **- The Challenge**
# Produce a program that:
# 1. Scrape the index webpage hosted at `cfcunderwriting.com`
# 2.Writes a list of *all externally loaded resources* (e.g. images/scripts/fonts not hosted
# on cfcunderwriting.com) to a JSON output file.
#
# 3.Enumerates the page's hyperlinks and identifies the location of the "Privacy Policy"
# page
# 4. Use the privacy policy URL identified in step 3 and scrape the pages content.
# Produce a case-insentitive word frequency count for all of the visible text on the page.
# Your frequency count should also be written to a JSON output file..
#
# **- Assessment Criteria**
# Treat the challenge as you would a real project so keep in mind readability,
# performance, code quality and comments.
#
# **- Submission**
# Please send back, by email, the URL to the github repository that you have checked
# your work into.
#
# **- Follow Up**
# Successful entries will be discussed at interview. We would love to understand what
# you would do if you had more time, and how you would expand the solution e.g.
# Adding support for international languages or making the solution more robust.

# %% [markdown]
# # Imports

# %%
from bs4 import BeautifulSoup as bs
import json
import re
import requests
import os
from pathlib import Path

from sklearn.feature_extraction.text import CountVectorizer
import nltk

# %% [markdown]
# # Parse Links Function
# Create function to get html from website and parse the html to extract all links
#
# Ideally the function would save the html first to reduce get requests from the server.
# Saving timestamped html files could allow for easier maintenance of the scraping functions.

# %%
def parse_links():
    """
    """
    url = "https://www.cfcunderwriting.com"
    parser = 'html.parser'  # or 'lxml' (preferred) or 'html5lib', if installed
#     parser = 'lxml'
    
    response = requests.get(url).text
    soup = bs(response, parser)
    
    links = []
    for link in soup.find_all(('link', 'a'), {'href':True}):
        links.append(link['href'])
    
    for link in soup.find_all(("script", 'iframe'), {'src':True}):
        links.append(link['src'])
        
    for link in soup.find_all('div', {'class':'img'}):
        links.append(link['style'])
    
    return links

parse_links()
# Out:
# ['https://www.cfcunderwriting.com/en-gb/',
#  'https://www.cfcunderwriting.com/en-gb/',
#  'https://www.cfcunderwriting.com/en-us/',
#  'https://www.cfcunderwriting.com/en-ca/',
#  'https://www.cfcunderwriting.com/en-au/',
#  'https://www.cfcunderwriting.com/en-gb/',
#  'https://fonts.googleapis.com/css?family=Montserrat:300,400,500,600,700',
#  'https://cdnjs.cloudflare.com/ajax/libs/cookieconsent2/3.1.0/cookieconsent.min.css',
#  'https://cdnjs.cloudflare.com/ajax/libs/twitter-bootstrap/4.1.3/css/bootstrap.min.css',
#  '/css/dist/bundle.css?v=20210825.1',
#  '/apple-touch-icon.png',
#  '/favicon-32x32.png',
#  '/favicon-16x16.png',
#  '/site.webmanifest',
#  '/safari-pinned-tab.svg',
#  '#',
#  'javascript:;',
#  '/en-gb/claims/',
#  '/en-gb/contact/',
#  '/en-gb/careers/',
#  '#',
#  '/locations/switch/?isocode=GB',
#  '/locations/switch/?isocode=US',
#  '/locations/switch/?isocode=CA',
#  '/locations/switch/?isocode=AU',
#  '/en-gb/',
#  'javascript:;',
#  '#',
#  '/locations/switch/?isocode=GB',
#  '/locations/switch/?isocode=US',
#  '/locations/switch/?isocode=CA',
#  '/locations/switch/?isocode=AU',
#  '/en-gb/claims/',
#  '/en-gb/contact/',
#  '/en-gb/careers/',
#  '/en-gb/platform/',
#  '/en-gb/products/class/contingency/',
#  '/en-gb/products/class/cyber/',
#  '/en-gb/products/class/environmental-liability/',
#  '/en-gb/products/class/excess-umbrella/',
#  '/en-gb/products/class/intellectual-property/',
#  '/en-gb/products/class/kidnap-ransom/',
#  '/en-gb/products/class/management-liability/',
#  '/en-gb/products/class/medical-malpractice/',
#  '/en-gb/products/class/product-recall/',
#  '/en-gb/products/class/professional-liability/',
#  '/en-gb/products/class/property-casualty/',
#  '/en-gb/products/class/terrorism/',
#  '/en-gb/products/class/transaction-liability/',
#  '/en-gb/products/industry/financial-institutions/',
#  '/en-gb/products/industry/ehealth/',
#  '/en-gb/products/industry/healthcare/',
#  '/en-gb/products/industry/life-science/',
#  '/en-gb/products/industry/manufacturing/',
#  '/en-gb/products/industry/media-entertainment/',
#  '/en-gb/products/industry/technology/',
#  '/en-gb/cyber/',
#  '/en-gb/cyber/',
#  '/en-gb/cyber/',
#  '/en-gb/products/class/cyber/#private-enterprise',
#  '/en-gb/products/class/cyber/#large-corporate',
#  '/en-gb/products/class/cyber/#cyber-excess',
#  '/en-gb/products/class/cyber/cyber-insurance-for-healthcare-providers/',
#  '/en-gb/products/class/cyber/cyber-insurance-for-retailers/',
#  '/en-gb/products/class/cyber/cyber-insurance-for-professional-services/',
#  '/en-gb/products/class/cyber/cyber-insurance-for-manufacturers/',
#  '/en-gb/products/class/cyber/cyber-insurance-for-construction/',
#  'https://resource.cfcunderwriting.com/connect-cyber',
#  'https://resource.cfcunderwriting.com/cyber-ir-app',
#  '/en-gb/claims/',
#  '/en-gb/resources/',
#  '/en-gb/resources/articles/2020/04/covid-19-turning-to-telemedicine/',
#  '/en-gb/resources/articles/',
#  '/en-gb/resources/case-studies/',
#  '/en-gb/resources/events/',
#  '/en-gb/resources/news/',
#  '/en-gb/resources/guides/',
#  '/en-gb/resources/webinars/',
#  '/en-gb/company/',
#  '/en-gb/resources/news/2021/06/cfc-syndicate-1988-opens-for-trading/',
#  '/en-gb/company/',
#  '/en-gb/company/find-an-underwriter/?r=uk&d=executive-committee&q=',
#  '/en-gb/resources/news/',
#  '/en-gb/company/#recognition',
#  '/en-gb/careers/',
#  '/en-gb/contact/',
#  'javascript:;',
#  '#section-0',
#  '/en-gb/resources/news/2020/09/cfcs-connect-wins-at-insurance-times-tech-innovation-awards/',
#  '/en-gb/resources/news/2020/10/cfcs-claims-team-wins-at-insurance-post-claims-awards/',
#  '/en-gb/resources/news/2020/12/cfcs-professional-liability-product-wins-5-star-excellence-award/',
#  '/en-gb/cyber/',
#  '/en-gb/products/class/intellectual-property/',
#  '/en-gb/products/industry/financial-institutions/',
#  '/en-gb/resources/news/2021/03/cfc-acquires-insane-technologies/',
#  'https://twitter.com/cfcunderwriting',
#  'https://www.facebook.com/cfcspecialistinsurance',
#  'https://www.linkedin.com/company/cfc-underwriting-ltd',
#  'https://www.youtube.com/user/CFCUnderwriting',
#  'https://www.instagram.com/cfc_underwriting/',
#  '/en-gb/products/class/cyber/',
#  '/en-gb/products/class/contingency/',
#  '/en-gb/products/class/environmental-liability/',
#  '/en-gb/products/class/excess-umbrella/',
#  '/en-gb/products/class/intellectual-property/',
#  '/en-gb/products/class/kidnap-ransom/',
#  '/en-gb/products/class/management-liability/',
#  '/en-gb/products/class/medical-malpractice/',
#  '/en-gb/products/class/product-recall/',
#  '/en-gb/products/class/professional-liability/',
#  '/en-gb/products/class/property-casualty/',
#  '/en-gb/products/class/terrorism/',
#  '/en-gb/products/class/transaction-liability/',
#  '/en-gb/products/industry/financial-institutions/',
#  '/en-gb/products/industry/ehealth/',
#  '/en-gb/products/industry/healthcare/',
#  '/en-gb/products/industry/life-science/',
#  '/en-gb/products/industry/manufacturing/',
#  '/en-gb/products/industry/media-entertainment/',
#  '/en-gb/products/industry/professional-services/',
#  '/en-gb/products/industry/technology/',
#  '/en-gb/resources/articles/',
#  '/en-gb/resources/case-studies/',
#  '/en-gb/resources/events/',
#  '/en-gb/resources/guides/',
#  '/en-gb/resources/webinars/',
#  '/en-gb/resources/news/',
#  '/en-gb/company/',
#  '/en-gb/why-cfc/',
#  '/en-gb/resources/news/',
#  '/en-gb/careers/',
#  '/en-gb/contact/',
#  '/en-gb/support/europe/',
#  '/en-gb/support/strategic-report/',
#  '/en-gb/gender-pay-gap-report/',
#  '/en-gb/support/complaints-procedure/',
#  '/en-gb/support/terms-of-use/',
#  '/en-gb/support/privacy-policy/',
#  '/en-gb/support/modern-slavery-statement/',
#  '/en-gb/gender-pay-gap-report/',
#  '#',
#  '#',
#  '#',
#  '/en-gb/support/privacy-policy/',
#  '#',
#  'https://www.googletagmanager.com/ns.html?id=GTM-NGGN5FB',
#  'https://cdnjs.cloudflare.com/ajax/libs/jquery/3.3.1/jquery.min.js',
#  'https://cdnjs.cloudflare.com/ajax/libs/twitter-bootstrap/4.1.3/js/bootstrap.min.js',
#  'https://cdnjs.cloudflare.com/ajax/libs/cookieconsent2/3.1.0/cookieconsent.min.js',
#  '/js/dist/gsap-bundle.js?v=20210825.1',
#  '/js/dist/bundle.js?v=20210825.1',
#  'https://www.google.com/recaptcha/api.js?render=6LemiyEaAAAAAGwb4nR8oX38fxyM36xjIGbwz6d4',
#  "background-image: url('https://cfccorpsite.azureedge.net/cache/2/c/b/7/c/6/2cb7c69a9a60c035b243a69e94d38757335fe859.jpg');",
#  "background-image: url('https://cfccorpsite.azureedge.net/cache/6/e/c/e/2/4/6ece24cc17c40ed64b4cb832116308d507a09485.png');",
#  "background-image: url('https://cfccorpsite.azureedge.net/cache/2/5/4/b/5/0/254b500f16ed796ab02c1fa84a4fa1c444e599e9.png');",
#  "background-image: url('https://cfccorpsite.azureedge.net/cache/9/b/0/a/d/b/9b0adbf131c63661d836a600698a5ac48a1e90f0.png');"]

# %% [markdown]
# # Return External Links Function
# Create function to return external links only from list of all links

# %%
def external_links(links):
    """
    """
    external_links = []
    for link in links:
        if re.match(".*(cfcunderwriting\.com+)[?\.]?", link, re.I):
            continue

        if re.match('^(http|https)://', link, re.I):
            external_links.append(link)    
            continue
        
        elif re.match("^background-image: url\('.*'", link, re.I):
            p = re.compile("'(.*?)'")
            m = p.search(link)
            link = m.group().replace("'","")
            external_links.append(link) 
            continue
    
    soup_social = soup.find(('div'), {'class':'social'})
    for link in soup_social.find_all(('link', 'a'), {'href':True}):
        external_links.remove(link['href'])
    
    
    return {"external_links":external_links}, len(external_links)

external_links(parse_links())

# %% [markdown]
# # Enumerate All Hyperlinks Function
# Create function to enumerate all hyperlinks hosted on the cfcunderwriting.com domain.
#
# Easiest, non-ideal solution was to explicitly exclude non cfcunderwriting.com
# Function can be improved to exclude all domains =/= cfcunderwriting.com

# %%
def enumerate_hyperlinks(links):
    """
    """
    hyperlinks = []
    for link in links:
        if re.match(".*(cloudflare\.com+)[?\.]?", link, re.I):
            continue
        elif re.match(".*(googleapis\.com+)[?\.]?", link, re.I):
            continue
        elif re.match(".*(google\.com+)[?\.]?", link, re.I):
            continue
            
        if re.match(".*(cfcunderwriting\.com+)[?\.]?", link, re.I):
            hyperlinks.append(link)
            continue

        if re.match('^(http|https)://', link, re.I):
            hyperlinks.append(link)
            continue
        
        elif re.match("^/en-", link, re.I):
            hyperlinks.append(link)
            continue
    
    hyperlinks_dict = {}
    for i, link in enumerate(hyperlinks):
        if re.match("^/en-gb", link, re.I):
            hyperlinks_dict[link.replace('/en-gb/', 'https://www.cfcunderwriting.com/en-gb/')] = i
#             hyperlinks_dict[i] = link.replace('/en-gb/', 'https://www.cfcunderwriting.com/en-gb/')
            continue
        else:
            hyperlinks_dict[link] = i
#             hyperlinks_dict[i] = link
    
    hyperlinks_enumerated = {}
    for i, link in enumerate(hyperlinks_dict.keys()):
        hyperlinks_enumerated[i] = link
    
#     return {"hyperlinks":hyperlinks}, len(hyperlinks)
    return hyperlinks_enumerated

enumerate_hyperlinks(parse_links())
# Out:
# {0: 'https://www.cfcunderwriting.com/en-gb/',
#  1: 'https://www.cfcunderwriting.com/en-us/',
#  2: 'https://www.cfcunderwriting.com/en-ca/',
#  3: 'https://www.cfcunderwriting.com/en-au/',
#  4: 'https://www.cfcunderwriting.com/en-gb/claims/',
#  5: 'https://www.cfcunderwriting.com/en-gb/contact/',
#  6: 'https://www.cfcunderwriting.com/en-gb/careers/',
#  7: 'https://www.cfcunderwriting.com/en-gb/platform/',
#  8: 'https://www.cfcunderwriting.com/en-gb/products/class/contingency/',
#  9: 'https://www.cfcunderwriting.com/en-gb/products/class/cyber/',
#  10: 'https://www.cfcunderwriting.com/en-gb/products/class/environmental-liability/',
#  11: 'https://www.cfcunderwriting.com/en-gb/products/class/excess-umbrella/',
#  12: 'https://www.cfcunderwriting.com/en-gb/products/class/intellectual-property/',
#  13: 'https://www.cfcunderwriting.com/en-gb/products/class/kidnap-ransom/',
#  14: 'https://www.cfcunderwriting.com/en-gb/products/class/management-liability/',
#  15: 'https://www.cfcunderwriting.com/en-gb/products/class/medical-malpractice/',
#  16: 'https://www.cfcunderwriting.com/en-gb/products/class/product-recall/',
#  17: 'https://www.cfcunderwriting.com/en-gb/products/class/professional-liability/',
#  18: 'https://www.cfcunderwriting.com/en-gb/products/class/property-casualty/',
#  19: 'https://www.cfcunderwriting.com/en-gb/products/class/terrorism/',
#  20: 'https://www.cfcunderwriting.com/en-gb/products/class/transaction-liability/',
#  21: 'https://www.cfcunderwriting.com/en-gb/products/industry/financial-institutions/',
#  22: 'https://www.cfcunderwriting.com/en-gb/products/industry/ehealth/',
#  23: 'https://www.cfcunderwriting.com/en-gb/products/industry/healthcare/',
#  24: 'https://www.cfcunderwriting.com/en-gb/products/industry/life-science/',
#  25: 'https://www.cfcunderwriting.com/en-gb/products/industry/manufacturing/',
#  26: 'https://www.cfcunderwriting.com/en-gb/products/industry/media-entertainment/',
#  27: 'https://www.cfcunderwriting.com/en-gb/products/industry/technology/',
#  28: 'https://www.cfcunderwriting.com/en-gb/cyber/',
#  29: 'https://www.cfcunderwriting.com/en-gb/products/class/cyber/#private-enterprise',
#  30: 'https://www.cfcunderwriting.com/en-gb/products/class/cyber/#large-corporate',
#  31: 'https://www.cfcunderwriting.com/en-gb/products/class/cyber/#cyber-excess',
#  32: 'https://www.cfcunderwriting.com/en-gb/products/class/cyber/cyber-insurance-for-healthcare-providers/',
#  33: 'https://www.cfcunderwriting.com/en-gb/products/class/cyber/cyber-insurance-for-retailers/',
#  34: 'https://www.cfcunderwriting.com/en-gb/products/class/cyber/cyber-insurance-for-professional-services/',
#  35: 'https://www.cfcunderwriting.com/en-gb/products/class/cyber/cyber-insurance-for-manufacturers/',
#  36: 'https://www.cfcunderwriting.com/en-gb/products/class/cyber/cyber-insurance-for-construction/',
#  37: 'https://resource.cfcunderwriting.com/connect-cyber',
#  38: 'https://resource.cfcunderwriting.com/cyber-ir-app',
#  39: 'https://www.cfcunderwriting.com/en-gb/resources/',
#  40: 'https://www.cfcunderwriting.com/en-gb/resources/articles/2020/04/covid-19-turning-to-telemedicine/',
#  41: 'https://www.cfcunderwriting.com/en-gb/resources/articles/',
#  42: 'https://www.cfcunderwriting.com/en-gb/resources/case-studies/',
#  43: 'https://www.cfcunderwriting.com/en-gb/resources/events/',
#  44: 'https://www.cfcunderwriting.com/en-gb/resources/news/',
#  45: 'https://www.cfcunderwriting.com/en-gb/resources/guides/',
#  46: 'https://www.cfcunderwriting.com/en-gb/resources/webinars/',
#  47: 'https://www.cfcunderwriting.com/en-gb/company/',
#  48: 'https://www.cfcunderwriting.com/en-gb/resources/news/2021/06/cfc-syndicate-1988-opens-for-trading/',
#  49: 'https://www.cfcunderwriting.com/en-gb/company/find-an-underwriter/?r=uk&d=executive-committee&q=',
#  50: 'https://www.cfcunderwriting.com/en-gb/company/#recognition',
#  51: 'https://www.cfcunderwriting.com/en-gb/resources/news/2020/09/cfcs-connect-wins-at-insurance-times-tech-innovation-awards/',
#  52: 'https://www.cfcunderwriting.com/en-gb/resources/news/2020/10/cfcs-claims-team-wins-at-insurance-post-claims-awards/',
#  53: 'https://www.cfcunderwriting.com/en-gb/resources/news/2020/12/cfcs-professional-liability-product-wins-5-star-excellence-award/',
#  54: 'https://www.cfcunderwriting.com/en-gb/resources/news/2021/03/cfc-acquires-insane-technologies/',
#  55: 'https://twitter.com/cfcunderwriting',
#  56: 'https://www.facebook.com/cfcspecialistinsurance',
#  57: 'https://www.linkedin.com/company/cfc-underwriting-ltd',
#  58: 'https://www.youtube.com/user/CFCUnderwriting',
#  59: 'https://www.instagram.com/cfc_underwriting/',
#  60: 'https://www.cfcunderwriting.com/en-gb/products/industry/professional-services/',
#  61: 'https://www.cfcunderwriting.com/en-gb/why-cfc/',
#  62: 'https://www.cfcunderwriting.com/en-gb/support/europe/',
#  63: 'https://www.cfcunderwriting.com/en-gb/support/strategic-report/',
#  64: 'https://www.cfcunderwriting.com/en-gb/gender-pay-gap-report/',
#  65: 'https://www.cfcunderwriting.com/en-gb/support/complaints-procedure/',
#  66: 'https://www.cfcunderwriting.com/en-gb/support/terms-of-use/',
#  67: 'https://www.cfcunderwriting.com/en-gb/support/privacy-policy/',
#  68: 'https://www.cfcunderwriting.com/en-gb/support/modern-slavery-statement/',
#  69: 'https://www.googletagmanager.com/ns.html?id=GTM-NGGN5FB'}

# %% [markdown]
# # Parse Privacy Policy Page Function
# Create function that parses the privacy page

# %% [markdown]
# Obtain Privacy Policy from list of hyperlinks
# Easy solution is to manually call the hyperlink based on its index
# Ideal solution is to find link that has `privacy` and/or `policy` using regex or equivalent

# %%
hyperlinks = enumerate_hyperlinks(parse_links())
hyperlinks[67]
# Out:
# 'https://www.cfcunderwriting.com/en-gb/support/privacy-policy/'

# %%
def parse_privacy_page():
    """
    """
    url = enumerate_hyperlinks(parse_links())[67]
    parser = 'html.parser'  # or 'lxml' (preferred) or 'html5lib', if installed
    
    response = requests.get(url).text
    soup = bs(response, parser)
    
    section_texts = []
    
    main_section = soup.find(["main"])
    
    sections = main_section.find_all(["h2", "p"])
    section_titles = soup.find_all('h2', class_='title')
    for section in sections:
        section_text = section.text.replace('\n',' ').lower()
        section_text = re.sub(r"(-?\d+)((\.(-?\d+))+)?", ' ', section_text)
        section_text = section_text.replace('\xa0',' ')
        section_texts.append(section_text)
        continue
    
    return section_texts

parse_privacy_page()
# Out:
# [' . our approach',
#  '  this privacy policy (the “policy”) sets out how we cfc underwriting limited (registered company number  ) headquartered at second floor,   gracechurch street, london ec v  aa and any of our subsidiaries or holding companies (together referred to as “cfc underwriting”, “our” or “we”) process the personal data of our customers, brokers and website visitors in the european union (“users”).',
#  '  if you have any questions about this policy, please contact our data protection officer (“dpo”) by clicking here.',
#  ' ',
#  ' . what information do we collect',
#  'personal data',
#  '  we will collect personal data when you obtain a quote for one of our products of services, or in the course of providing you with one of our products of services. we will also collect personal data when you register with us or provide your information through our website. the types of information we collect may include:',
#  '  information you provide us in your insurance application, including names, addresses, date of birth or other information provided by you in your application for insurance;',
#  '  information you provide us to help us carry out our obligations under any insurance contract in place between us and you;',
#  '  information you provide us relating to an insurance claim you make; and',
#  '  information you provide us through one of our mobile apps or customer portals.',
#  '  we will use your personal data, and may share your personal data with other third parties acting on our behalf, for one or more of the following purposes:',
#  '  to analyse your insurance needs;',
#  '  to give you an estimate or provide you with a quote for one of our policies;',
#  '  to administer or carry out our obligations under any insurance contract in place between us and you;',
#  '  to assess and adjust any insurance claim you make;',
#  '  to assess and respond to a complaint you might make relating to our products or services; and',
#  '  to ensure the security of your account and our business, preventing or detecting fraud or abuses of our website, for example, by requesting verification information in order to reset your account password.',
#  '  in certain circumstances, we may need to collect sensitive personal data about you, which may include information about:',
#  '  your physical or mental health condition, or the physical or mental health condition of members of your family, or the physical or mental health condition of one of your employees; and',
#  '  any criminal offence or alleged criminal offence committed by you, or members of your family, or one of your employees.',
#  '  we will only use such sensitive personal data to:',
#  '  to administer or carry out our obligations under any insurance contract in place between us and you;',
#  '  to assess and adjust any insurance claim you make; and',
#  '  to assess and respond to a complaint you might make relating to our products or services.',
#  '  we may also collect non-personal data (i.e. information that has been sufficiently anonymised and aggregated such that you cannot be identified directly or indirectly from it). further information about our use of non-personal data is included in paragraph   (below).',
#  ' ',
#  ' . information for marketing purposes',
#  '  where you have consented to us using your personal data for marketing purposes, we may use your information as follows:',
#  '  to provide you with information, products or services that you request from us or which we feel may interest you; and',
#  '  for market research purposes, where we may contact you to ask for your feedback.',
#  '  if at any time after you have consented to us using your information for marketing purposes you wish us to stop using your information for these purposes, please email us at optout@cfcunderwriting.com.',
#  ' ',
#  ' . grounds for processing',
#  '  to process your data lawfully we need to rely on one or more valid legal grounds. our primary legal ground is that we need the data to fulfil our contract with you or to take certain steps prior to entering our contract with you. however, there may be circumstances where we also rely on other valid legal grounds, such as:',
#  '  your consent to particular processing activities. for example, where you have consented to us using your information for marketing purposes;',
#  '  our legitimate interests as a business (except where your interests or fundamental rights override these). for example, it is within our legitimate interests to use your data to prevent or detect fraud or abuses of our website; or',
#  '  our compliance with a legal obligation to which cfc underwriting is subject. for example, we have a regulatory duty to investigate and respond to complaints made against us and may need to process your data as part of such investigation.',
#  ' ',
#  ' . disclosure of your information',
#  '  there are circumstances where we may wish to disclose or are compelled to disclose your personal data to third parties. this will only take place in accordance with the applicable law and for the purposes listed above. these scenarios include disclosure:',
#  '  to our subsidiaries, branches or associated offices;',
#  '  to our outsourced service providers or suppliers to facilitate the provision of our services or products to our users, for example, the disclosure to our data centre provider for the safe keeping of your personal data, webhosting provider through which your personal data may be collected, identity verification partners in order to verify your identity against public databases;',
#  '  to third party service providers and consultants in order to protect the security or integrity of our business, including our databases and systems and for business continuity reasons;',
#  '  to our carriers and/or our reinsurers, to facilitate the provision of our services or products to you;',
#  '  to another legal entity, on a temporary or permanent basis, for the purposes of a joint venture, collaboration, financing, sale, merger, reorganisation, change of legal form, dissolution or similar event. in the case of a merger or sale, your personal data will be permanently transferred to a successor company;',
#  '  to legal advisors who may need to manage or litigate an insurance claim;',
#  '  to public authorities where we are required by law to do so; and',
#  '  to any other third party where you have provided your consent.',
#  ' ',
#  ' . international transfer of personal data',
#  '  we may transfer your personal data to a third party in countries outside the uk for further processing in accordance with the purposes set out in this policy. in particular, your personal data may be transferred throughout the cfc underwriting group and to our outsourced service providers located abroad. in these circumstances we will, as required by applicable law, ensure that your privacy rights are adequately protected by appropriate technical, organisation, contractual or other lawful means. please contact the data protection officer for a copy of the safeguards which we have put in place to protect your personal data and privacy rights in these circumstances.',
#  ' ',
#  ' . retention of personal data',
#  '  if you are, or have previously been, a customer of ours then we may continue to hold and process your information for the purpose of continuing to carry out our obligations in connection with the insurance contract between us and you. we will continue to hold and process your information for the duration of the insurance contract and for a reasonable period of time afterwards as required by law.',
#  '  we may keep an anonymised form of your personal data, which will no longer refer to you, for statistical purposes without time limits, to the extent that we have a legitimate and lawful interest in doing so.',
#  ' ',
#  ' . data subject rights',
#  '  data protection law provides individuals with numerous rights, including the right to: access, rectify, erase, restrict, transport, and object to the processing of, their personal data. individuals also have the right to lodge a complaint with the relevant data protection authority if they believe that their personal data is not being processed in accordance with applicable data protection law.',
#  '  right to make subject access request (sar). where we are processing your personal data as a data controller you may, where permitted by applicable law, request copies of your personal data. if you would like to make a sar, i.e. a request for copies of the personal data we hold about you, you may do so by writing to the data protection officer whose contact details are above. the request should make clear that a sar is being made. you may also be required to submit a proof of your identity and a fee.',
#  '  right to rectification. you may request that we rectify any inaccurate and/or complete any incomplete personal data.',
#  '  right to withdraw consent. you may, as permitted by applicable law, withdraw your consent to the processing of your personal data at any time. such withdrawal will not affect the lawfulness of processing based on your previous consent. please note that if you withdraw your consent, you may not be able to benefit certain service features for which the processing of your personal data is essential.',
#  '  right to object to processing. you may, as permitted by applicable law, request that we stop processing your personal data.',
#  '  right to erasure. you may request that we erase your personal data and we will comply, unless there is a lawful reason for not doing so. for example, there may be an overriding legitimate ground for keeping your personal data, such as a legal obligation that we have to comply with, or if retention is necessary for us to comply with our legal obligations.',
#  '  your right to lodge a complaint with the supervisory authority. we suggest that you contact us about any questions or if you have a complaint in relation to how we process your personal data. however, you do have the right to contact the relevant supervisory authority directly. to contact the information commissioner’s office in the united kingdom, please visit the ico website for instructions.',
#  ' ',
#  ' . non-personal data',
#  '  we collect and use the following types of non-personal information:',
#  '  internet protocol (ip) addresses. when you visit our site, we log your ip address (the unique address which identifies your computer on the internet). we use ip addresses to collect broad geographic information on our site visitor, and to optimise our website. we do not link ip addresses to personally identifiable information.',
#  '  cookies. cookies are small text files that are placed on your computer by the websites you visit. they are widely used in order to make websites works, or work more efficiently, as well as to provide information to the owners of the site. you may delete and block all cookies from this website, but if you choose to do so parts of this site may not work.',
#  '  session cookies. sections of this website use ‘session cookies’ which help us to improve our website, assist with the navigation through certain parts of the website and deliver a better and more personalised service. session cookie specifically enable us to keep track of your movement from page to page within the website so you don’t get asked for the same information each time you navigate to a new page. they also allow us to recognise you so that any page changes.',
#  '  google analytics. these cookies are used to collect information about how visitors use our website. we use the information to compile reports and to help us improve our website. the cookies collect information in an anonymous form, including the number of visitors, where visitors have come to our website from and which pages they visit. for more information on google’s privacy policy click here.',
#  '  google recaptcha. this site uses google’s recaptcha which collects personal and non-personal information. recaptcha uses an advanced risk analysis engine and adaptive challenges to keep malicious software from engaging on our website. this program is subject to its own privacy policy which we encourage you to review before using our website.',
#  '  online surveys. from time to time we may invite our website visitor or our customers to participate in an online survey about our online services or our products and related services. your participation is optional, and any information we collect is only used to improve the products and services we offer to our website users or customers. these online surveys are provided by typeform.',
#  ' ',
#  ' . linked websites',
#  'please note that any websites that may be linked to our websites are subject to their own privacy policy.']

# %% [markdown]
# # Word Frequency Function - SKL
# Create function that determines the word frequency of the privacy page

# %%
def word_frequency_counter_skl():

    corpus = parse_privacy_page()
    cv = CountVectorizer()
    cv_fit = cv.fit_transform(corpus)
    words = cv.get_feature_names()
    counts = cv_fit.toarray().sum(axis=0)
    word_frequencies = {word:counts[i] for i, word in enumerate(words)}
    return {'word_frequencies': word_frequencies}

word_frequency_counter_skl()
# Out:
# {'word_frequencies': {'aa': 1,
#   'able': 1,
#   'about': 8,
#   'above': 2,
#   'abroad': 1,
#   'abuses': 2,
#   'access': 2,
#   'accordance': 3,
#   'account': 2,
#   'acting': 1,
#   'activities': 1,
#   'adaptive': 1,
#   'address': 2,
#   'addresses': 4,
#   'adequately': 1,
#   'adjust': 2,
#   'administer': 2,
#   'advanced': 1,
#   'advisors': 1,
#   'affect': 1,
#   'after': 1,
#   'afterwards': 1,
#   'against': 2,
#   'aggregated': 1,
#   'all': 1,
#   'alleged': 1,
#   'allow': 1,
#   'also': 6,
#   'an': 8,
#   'analyse': 1,
#   'analysis': 1,
#   'analytics': 1,
#   'and': 48,
#   'anonymised': 2,
#   'anonymous': 1,
#   'another': 1,
#   'any': 17,
#   'applicable': 6,
#   'application': 2,
#   'approach': 1,
#   'appropriate': 1,
#   'apps': 1,
#   'are': 13,
#   'as': 13,
#   'ask': 1,
#   'asked': 1,
#   'assess': 4,
#   'assist': 1,
#   'associated': 1,
#   'at': 4,
#   'authorities': 1,
#   'authority': 3,
#   'based': 1,
#   'basis': 1,
#   'be': 9,
#   'been': 2,
#   'before': 1,
#   'behalf': 1,
#   'being': 2,
#   'believe': 1,
#   'below': 1,
#   'benefit': 1,
#   'better': 1,
#   'between': 4,
#   'birth': 1,
#   'block': 1,
#   'branches': 1,
#   'broad': 1,
#   'brokers': 1,
#   'business': 4,
#   'but': 1,
#   'by': 14,
#   'cannot': 1,
#   'carriers': 1,
#   'carry': 4,
#   'case': 1,
#   'centre': 1,
#   'certain': 4,
#   'cfc': 4,
#   'cfcunderwriting': 1,
#   'challenges': 1,
#   'change': 1,
#   'changes': 1,
#   'choose': 1,
#   'circumstances': 5,
#   'claim': 4,
#   'clear': 1,
#   'click': 1,
#   'clicking': 1,
#   'collaboration': 1,
#   'collect': 11,
#   'collected': 1,
#   'collects': 1,
#   'com': 1,
#   'come': 1,
#   'commissioner': 1,
#   'committed': 1,
#   'companies': 1,
#   'company': 2,
#   'compelled': 1,
#   'compile': 1,
#   'complaint': 5,
#   'complaints': 1,
#   'complete': 1,
#   'compliance': 1,
#   'comply': 3,
#   'computer': 2,
#   'condition': 3,
#   'connection': 1,
#   'consent': 6,
#   'consented': 3,
#   'consultants': 1,
#   'contact': 7,
#   'continue': 2,
#   'continuing': 1,
#   'continuity': 1,
#   'contract': 7,
#   'contractual': 1,
#   'controller': 1,
#   'cookie': 1,
#   'cookies': 7,
#   'copies': 2,
#   'copy': 1,
#   'countries': 1,
#   'course': 1,
#   'criminal': 2,
#   'customer': 2,
#   'customers': 3,
#   'data': 47,
#   'databases': 2,
#   'date': 1,
#   'delete': 1,
#   'deliver': 1,
#   'details': 1,
#   'detect': 1,
#   'detecting': 1,
#   'directly': 2,
#   'disclose': 2,
#   'disclosure': 3,
#   'dissolution': 1,
#   'do': 6,
#   'doing': 2,
#   'don': 1,
#   'dpo': 1,
#   'duration': 1,
#   'duty': 1,
#   'each': 1,
#   'ec': 1,
#   'efficiently': 1,
#   'email': 1,
#   'employees': 2,
#   'enable': 1,
#   'encourage': 1,
#   'engaging': 1,
#   'engine': 1,
#   'ensure': 2,
#   'entering': 1,
#   'entity': 1,
#   'erase': 2,
#   'erasure': 1,
#   'essential': 1,
#   'estimate': 1,
#   'european': 1,
#   'event': 1,
#   'example': 6,
#   'except': 1,
#   'extent': 1,
#   'facilitate': 2,
#   'family': 2,
#   'features': 1,
#   'fee': 1,
#   'feedback': 1,
#   'feel': 1,
#   'files': 1,
#   'financing': 1,
#   'floor': 1,
#   'following': 2,
#   'follows': 1,
#   'for': 36,
#   'form': 3,
#   'fraud': 2,
#   'from': 7,
#   'fulfil': 1,
#   'fundamental': 1,
#   'further': 2,
#   'geographic': 1,
#   'get': 1,
#   'give': 1,
#   'google': 4,
#   'gracechurch': 1,
#   'ground': 2,
#   'grounds': 3,
#   'group': 1,
#   'has': 1,
#   'have': 14,
#   'headquartered': 1,
#   'health': 3,
#   'help': 3,
#   'here': 2,
#   'hold': 3,
#   'holding': 1,
#   'how': 3,
#   'however': 2,
#   'ico': 1,
#   'identifiable': 1,
#   'identified': 1,
#   'identifies': 1,
#   'identity': 3,
#   'if': 9,
#   'improve': 3,
#   'in': 29,
#   'inaccurate': 1,
#   'include': 3,
#   'included': 1,
#   'including': 4,
#   'incomplete': 1,
#   'indirectly': 1,
#   'individuals': 2,
#   'information': 33,
#   'instructions': 1,
#   'insurance': 12,
#   'integrity': 1,
#   'interest': 2,
#   'interests': 3,
#   'international': 1,
#   'internet': 2,
#   'investigate': 1,
#   'investigation': 1,
#   'invite': 1,
#   'ip': 4,
#   'is': 12,
#   'it': 2,
#   'its': 1,
#   'joint': 1,
#   'keep': 3,
#   'keeping': 2,
#   'kingdom': 1,
#   'law': 9,
#   'lawful': 3,
#   'lawfully': 1,
#   'lawfulness': 1,
#   'legal': 9,
#   'legitimate': 4,
#   'like': 1,
#   'limited': 1,
#   'limits': 1,
#   'link': 1,
#   'linked': 2,
#   'listed': 1,
#   'litigate': 1,
#   'located': 1,
#   'lodge': 2,
#   'log': 1,
#   'london': 1,
#   'longer': 1,
#   'made': 2,
#   'make': 9,
#   'malicious': 1,
#   'manage': 1,
#   'market': 1,
#   'marketing': 4,
#   'may': 30,
#   'means': 1,
#   'members': 2,
#   'mental': 3,
#   'merger': 2,
#   'might': 2,
#   'mobile': 1,
#   'more': 5,
#   'movement': 1,
#   'names': 1,
#   'navigate': 1,
#   'navigation': 1,
#   'necessary': 1,
#   'need': 5,
#   'needs': 1,
#   'new': 1,
#   'no': 1,
#   'non': 5,
#   'not': 6,
#   'note': 2,
#   'number': 2,
#   'numerous': 1,
#   'object': 2,
#   'obligation': 2,
#   'obligations': 5,
#   'obtain': 1,
#   'of': 53,
#   'offence': 2,
#   'offer': 1,
#   'office': 1,
#   'officer': 3,
#   'offices': 1,
#   'on': 10,
#   'one': 8,
#   'online': 4,
#   'only': 3,
#   'optimise': 1,
#   'optional': 1,
#   'optout': 1,
#   'or': 51,
#   'order': 4,
#   'organisation': 1,
#   'other': 5,
#   'our': 54,
#   'ours': 1,
#   'out': 6,
#   'outside': 1,
#   'outsourced': 2,
#   'override': 1,
#   'overriding': 1,
#   'own': 2,
#   'owners': 1,
#   'page': 4,
#   'pages': 1,
#   'paragraph': 1,
#   'part': 1,
#   'participate': 1,
#   'participation': 1,
#   'particular': 2,
#   'parties': 2,
#   'partners': 1,
#   'parts': 2,
#   'party': 3,
#   'password': 1,
#   'period': 1,
#   'permanent': 1,
#   'permanently': 1,
#   'permitted': 3,
#   'personal': 37,
#   'personalised': 1,
#   'personally': 1,
#   'physical': 3,
#   'place': 5,
#   'placed': 1,
#   'please': 6,
#   'policies': 1,
#   'policy': 7,
#   'portals': 1,
#   'prevent': 1,
#   'preventing': 1,
#   'previous': 1,
#   'previously': 1,
#   'primary': 1,
#   'prior': 1,
#   'privacy': 6,
#   'process': 6,
#   'processed': 1,
#   'processing': 10,
#   'products': 9,
#   'program': 1,
#   'proof': 1,
#   'protect': 2,
#   'protected': 1,
#   'protection': 6,
#   'protocol': 1,
#   'provide': 8,
#   'provided': 3,
#   'provider': 2,
#   'providers': 3,
#   'provides': 1,
#   'providing': 1,
#   'provision': 2,
#   'public': 2,
#   'purpose': 1,
#   'purposes': 11,
#   'put': 1,
#   'questions': 2,
#   'quote': 2,
#   'reason': 1,
#   'reasonable': 1,
#   'reasons': 1,
#   'recaptcha': 3,
#   'recognise': 1,
#   'rectification': 1,
#   'rectify': 2,
#   'refer': 1,
#   'referred': 1,
#   'register': 1,
#   'registered': 1,
#   'regulatory': 1,
#   'reinsurers': 1,
#   'related': 1,
#   'relating': 3,
#   'relation': 1,
#   'relevant': 2,
#   'rely': 2,
#   'reorganisation': 1,
#   'reports': 1,
#   'request': 8,
#   'requesting': 1,
#   'required': 4,
#   'research': 1,
#   'reset': 1,
#   'respond': 3,
#   'restrict': 1,
#   'retention': 2,
#   'review': 1,
#   'right': 9,
#   'rights': 5,
#   'risk': 1,
#   'safe': 1,
#   'safeguards': 1,
#   'sale': 2,
#   'same': 1,
#   'sar': 3,
#   'scenarios': 1,
#   'second': 1,
#   'sections': 1,
#   'security': 2,
#   'sensitive': 2,
#   'service': 5,
#   'services': 10,
#   'session': 3,
#   'set': 1,
#   'sets': 1,
#   'share': 1,
#   'should': 1,
#   'similar': 1,
#   'site': 5,
#   'small': 1,
#   'so': 7,
#   'software': 1,
#   'specifically': 1,
#   'statistical': 1,
#   'steps': 1,
#   'stop': 2,
#   'street': 1,
#   'subject': 5,
#   'submit': 1,
#   'subsidiaries': 2,
#   'successor': 1,
#   'such': 6,
#   'sufficiently': 1,
#   'suggest': 1,
#   'supervisory': 2,
#   'suppliers': 1,
#   'survey': 1,
#   'surveys': 2,
#   'systems': 1,
#   'take': 2,
#   'technical': 1,
#   'temporary': 1,
#   'text': 1,
#   'that': 18,
#   'the': 59,
#   'their': 3,
#   'then': 1,
#   'there': 4,
#   'these': 7,
#   'they': 4,
#   'third': 5,
#   'this': 9,
#   'through': 4,
#   'throughout': 1,
#   'time': 7,
#   'to': 111,
#   'together': 1,
#   'track': 1,
#   'transfer': 2,
#   'transferred': 2,
#   'transport': 1,
#   'typeform': 1,
#   'types': 2,
#   'uk': 1,
#   'under': 3,
#   'underwriting': 4,
#   'union': 1,
#   'unique': 1,
#   'united': 1,
#   'unless': 1,
#   'us': 23,
#   'use': 10,
#   'used': 3,
#   'users': 3,
#   'uses': 2,
#   'using': 5,
#   'valid': 2,
#   'venture': 1,
#   'verification': 2,
#   'verify': 1,
#   'visit': 4,
#   'visitor': 2,
#   'visitors': 4,
#   'we': 44,
#   'webhosting': 1,
#   'website': 18,
#   'websites': 5,
#   'well': 1,
#   'what': 1,
#   'when': 3,
#   'where': 11,
#   'which': 12,
#   'who': 1,
#   'whose': 1,
#   'widely': 1,
#   'will': 11,
#   'wish': 2,
#   'with': 18,
#   'withdraw': 3,
#   'withdrawal': 1,
#   'within': 2,
#   'without': 1,
#   'work': 2,
#   'works': 1,
#   'would': 1,
#   'writing': 1,
#   'you': 59,
#   'your': 56}}

# %% [markdown]
# Function can be optimized to exclude the following `words` that don't actually exist
# ec
# ip
# sar

# %% [markdown]
# # Word Frequency Function - NLTK
# Alternate function to calculate word frequencies:

# %%
def word_frequency_counter_nltk():
    corpus = ' '.join(parse_privacy_page())
    words = nltk.tokenize.word_tokenize(corpus)
    counts = nltk.FreqDist(words)

    word_frequencies = dict((word, freq) for word, freq in counts.items() if word.isalpha())
    return {'word_frequencies': word_frequencies}

word_frequency_counter_nltk()
# Out:
# {'word_frequencies': {'our': 54,
#   'approach': 1,
#   'this': 9,
#   'privacy': 6,
#   'policy': 7,
#   'the': 59,
#   'sets': 1,
#   'out': 6,
#   'how': 3,
#   'we': 44,
#   'cfc': 4,
#   'underwriting': 4,
#   'limited': 1,
#   'registered': 1,
#   'company': 2,
#   'number': 2,
#   'headquartered': 1,
#   'at': 4,
#   'second': 1,
#   'floor': 1,
#   'gracechurch': 1,
#   'street': 1,
#   'london': 1,
#   'ec': 1,
#   'v': 1,
#   'aa': 1,
#   'and': 46,
#   'any': 17,
#   'of': 53,
#   'subsidiaries': 2,
#   'or': 49,
#   'holding': 1,
#   'companies': 1,
#   'together': 1,
#   'referred': 1,
#   'to': 111,
#   'as': 13,
#   'process': 6,
#   'personal': 32,
#   'data': 47,
#   'customers': 3,
#   'brokers': 1,
#   'website': 18,
#   'visitors': 4,
#   'in': 29,
#   'european': 1,
#   'union': 1,
#   'users': 3,
#   'if': 9,
#   'you': 59,
#   'have': 14,
#   'questions': 2,
#   'about': 8,
#   'please': 6,
#   'contact': 7,
#   'protection': 6,
#   'officer': 3,
#   'dpo': 1,
#   'by': 14,
#   'clicking': 1,
#   'here': 2,
#   'what': 1,
#   'information': 33,
#   'do': 6,
#   'collect': 11,
#   'will': 11,
#   'when': 3,
#   'obtain': 1,
#   'a': 29,
#   'quote': 2,
#   'for': 36,
#   'one': 8,
#   'products': 9,
#   'services': 10,
#   'course': 1,
#   'providing': 1,
#   'with': 18,
#   'also': 6,
#   'register': 1,
#   'us': 23,
#   'provide': 8,
#   'your': 56,
#   'through': 4,
#   'types': 2,
#   'may': 30,
#   'include': 3,
#   'insurance': 12,
#   'application': 2,
#   'including': 4,
#   'names': 1,
#   'addresses': 4,
#   'date': 1,
#   'birth': 1,
#   'other': 5,
#   'provided': 3,
#   'help': 3,
#   'carry': 4,
#   'obligations': 5,
#   'under': 3,
#   'contract': 7,
#   'place': 5,
#   'between': 4,
#   'relating': 3,
#   'an': 8,
#   'claim': 4,
#   'make': 9,
#   'mobile': 1,
#   'apps': 1,
#   'customer': 2,
#   'portals': 1,
#   'use': 10,
#   'share': 1,
#   'third': 5,
#   'parties': 2,
#   'acting': 1,
#   'on': 10,
#   'behalf': 1,
#   'more': 5,
#   'following': 2,
#   'purposes': 11,
#   'analyse': 1,
#   'needs': 1,
#   'give': 1,
#   'estimate': 1,
#   'policies': 1,
#   'administer': 2,
#   'assess': 4,
#   'adjust': 2,
#   'respond': 3,
#   'complaint': 5,
#   'might': 2,
#   'ensure': 2,
#   'security': 2,
#   'account': 2,
#   'business': 4,
#   'preventing': 1,
#   'detecting': 1,
#   'fraud': 2,
#   'abuses': 2,
#   'example': 6,
#   'requesting': 1,
#   'verification': 2,
#   'order': 4,
#   'reset': 1,
#   'password': 1,
#   'certain': 4,
#   'circumstances': 5,
#   'need': 5,
#   'sensitive': 2,
#   'which': 12,
#   'physical': 3,
#   'mental': 3,
#   'health': 3,
#   'condition': 3,
#   'members': 2,
#   'family': 2,
#   'employees': 2,
#   'criminal': 2,
#   'offence': 2,
#   'alleged': 1,
#   'committed': 1,
#   'only': 3,
#   'such': 6,
#   'that': 18,
#   'has': 1,
#   'been': 2,
#   'sufficiently': 1,
#   'anonymised': 2,
#   'aggregated': 1,
#   'can': 1,
#   'not': 7,
#   'be': 9,
#   'identified': 1,
#   'directly': 2,
#   'indirectly': 1,
#   'from': 7,
#   'it': 2,
#   'further': 2,
#   'is': 12,
#   'included': 1,
#   'paragraph': 1,
#   'below': 1,
#   'marketing': 4,
#   'where': 11,
#   'consented': 3,
#   'using': 5,
#   'follows': 1,
#   'request': 8,
#   'feel': 1,
#   'interest': 2,
#   'market': 1,
#   'research': 1,
#   'ask': 1,
#   'feedback': 1,
#   'time': 7,
#   'after': 1,
#   'wish': 2,
#   'stop': 2,
#   'these': 7,
#   'email': 1,
#   'optout': 1,
#   'grounds': 3,
#   'processing': 10,
#   'lawfully': 1,
#   'rely': 2,
#   'valid': 2,
#   'legal': 9,
#   'primary': 1,
#   'ground': 2,
#   'fulfil': 1,
#   'take': 2,
#   'steps': 1,
#   'prior': 1,
#   'entering': 1,
#   'however': 2,
#   'there': 4,
#   'consent': 6,
#   'particular': 2,
#   'activities': 1,
#   'legitimate': 4,
#   'interests': 3,
#   'except': 1,
#   'fundamental': 1,
#   'rights': 5,
#   'override': 1,
#   'within': 2,
#   'prevent': 1,
#   'detect': 1,
#   'compliance': 1,
#   'obligation': 2,
#   'subject': 5,
#   'regulatory': 1,
#   'duty': 1,
#   'investigate': 1,
#   'complaints': 1,
#   'made': 2,
#   'against': 2,
#   'part': 1,
#   'investigation': 1,
#   'disclosure': 3,
#   'are': 13,
#   'disclose': 2,
#   'compelled': 1,
#   'accordance': 3,
#   'applicable': 6,
#   'law': 9,
#   'listed': 1,
#   'above': 2,
#   'scenarios': 1,
#   'branches': 1,
#   'associated': 1,
#   'offices': 1,
#   'outsourced': 2,
#   'service': 5,
#   'providers': 3,
#   'suppliers': 1,
#   'facilitate': 2,
#   'provision': 2,
#   'centre': 1,
#   'provider': 2,
#   'safe': 1,
#   'keeping': 2,
#   'webhosting': 1,
#   'collected': 1,
#   'identity': 3,
#   'partners': 1,
#   'verify': 1,
#   'public': 2,
#   'databases': 2,
#   'party': 3,
#   'consultants': 1,
#   'protect': 2,
#   'integrity': 1,
#   'systems': 1,
#   'continuity': 1,
#   'reasons': 1,
#   'carriers': 1,
#   'reinsurers': 1,
#   'another': 1,
#   'entity': 1,
#   'temporary': 1,
#   'permanent': 1,
#   'basis': 1,
#   'joint': 1,
#   'venture': 1,
#   'collaboration': 1,
#   'financing': 1,
#   'sale': 2,
#   'merger': 2,
#   'reorganisation': 1,
#   'change': 1,
#   'form': 3,
#   'dissolution': 1,
#   'similar': 1,
#   'event': 1,
#   'case': 1,
#   'permanently': 1,
#   'transferred': 2,
#   'successor': 1,
#   'advisors': 1,
#   'who': 1,
#   'manage': 1,
#   'litigate': 1,
#   'authorities': 1,
#   'required': 4,
#   'so': 7,
#   'international': 1,
#   'transfer': 2,
#   'countries': 1,
#   'outside': 1,
#   'uk': 1,
#   'set': 1,
#   'throughout': 1,
#   'group': 1,
#   'located': 1,
#   'abroad': 1,
#   'adequately': 1,
#   'protected': 1,
#   'appropriate': 1,
#   'technical': 1,
#   'organisation': 1,
#   'contractual': 1,
#   'lawful': 3,
#   'means': 1,
#   'copy': 1,
#   'safeguards': 1,
#   'put': 1,
#   'retention': 2,
#   'previously': 1,
#   'ours': 1,
#   'then': 1,
#   'continue': 2,
#   'hold': 3,
#   'purpose': 1,
#   'continuing': 1,
#   'connection': 1,
#   'duration': 1,
#   'reasonable': 1,
#   'period': 1,
#   'afterwards': 1,
#   'keep': 3,
#   'no': 1,
#   'longer': 1,
#   'refer': 1,
#   'statistical': 1,
#   'without': 1,
#   'limits': 1,
#   'extent': 1,
#   'doing': 2,
#   'provides': 1,
#   'individuals': 2,
#   'numerous': 1,
#   'right': 9,
#   'access': 2,
#   'rectify': 2,
#   'erase': 2,
#   'restrict': 1,
#   'transport': 1,
#   'object': 2,
#   'their': 3,
#   'lodge': 2,
#   'relevant': 2,
#   'authority': 3,
#   'they': 4,
#   'believe': 1,
#   'being': 2,
#   'processed': 1,
#   'sar': 3,
#   'controller': 1,
#   'permitted': 3,
#   'copies': 2,
#   'would': 1,
#   'like': 1,
#   'writing': 1,
#   'whose': 1,
#   'details': 1,
#   'should': 1,
#   'clear': 1,
#   'submit': 1,
#   'proof': 1,
#   'fee': 1,
#   'rectification': 1,
#   'inaccurate': 1,
#   'complete': 1,
#   'incomplete': 1,
#   'withdraw': 3,
#   'withdrawal': 1,
#   'affect': 1,
#   'lawfulness': 1,
#   'based': 1,
#   'previous': 1,
#   'note': 2,
#   'able': 1,
#   'benefit': 1,
#   'features': 1,
#   'essential': 1,
#   'erasure': 1,
#   'comply': 3,
#   'unless': 1,
#   'reason': 1,
#   'overriding': 1,
#   'necessary': 1,
#   'supervisory': 2,
#   'suggest': 1,
#   'relation': 1,
#   'commissioner': 1,
#   's': 3,
#   'office': 1,
#   'united': 1,
#   'kingdom': 1,
#   'visit': 4,
#   'ico': 1,
#   'instructions': 1,
#   'internet': 2,
#   'protocol': 1,
#   'ip': 4,
#   'site': 5,
#   'log': 1,
#   'address': 2,
#   'unique': 1,
#   'identifies': 1,
#   'computer': 2,
#   'broad': 1,
#   'geographic': 1,
#   'visitor': 2,
#   'optimise': 1,
#   'link': 1,
#   'personally': 1,
#   'identifiable': 1,
#   'cookies': 7,
#   'small': 1,
#   'text': 1,
#   'files': 1,
#   'placed': 1,
#   'websites': 5,
#   'widely': 1,
#   'used': 3,
#   'works': 1,
#   'work': 2,
#   'efficiently': 1,
#   'well': 1,
#   'owners': 1,
#   'delete': 1,
#   'block': 1,
#   'all': 1,
#   'but': 1,
#   'choose': 1,
#   'parts': 2,
#   'session': 3,
#   'sections': 1,
#   'improve': 3,
#   'assist': 1,
#   'navigation': 1,
#   'deliver': 1,
#   'better': 1,
#   'personalised': 1,
#   'cookie': 1,
#   'specifically': 1,
#   'enable': 1,
#   'track': 1,
#   'movement': 1,
#   'page': 4,
#   'don': 1,
#   't': 1,
#   'get': 1,
#   'asked': 1,
#   'same': 1,
#   'each': 1,
#   'navigate': 1,
#   'new': 1,
#   'allow': 1,
#   'recognise': 1,
#   'changes': 1,
#   'google': 4,
#   'analytics': 1,
#   'compile': 1,
#   'reports': 1,
#   'anonymous': 1,
#   'come': 1,
#   'pages': 1,
#   'click': 1,
#   'recaptcha': 3,
#   'uses': 2,
#   'collects': 1,
#   'advanced': 1,
#   'risk': 1,
#   'analysis': 1,
#   'engine': 1,
#   'adaptive': 1,
#   'challenges': 1,
#   'malicious': 1,
#   'software': 1,
#   'engaging': 1,
#   'program': 1,
#   'its': 1,
#   'own': 2,
#   'encourage': 1,
#   'review': 1,
#   'before': 1,
#   'online': 4,
#   'surveys': 2,
#   'invite': 1,
#   'participate': 1,
#   'survey': 1,
#   'related': 1,
#   'participation': 1,
#   'optional': 1,
#   'offer': 1,
#   'typeform': 1,
#   'linked': 2}}

# %% [markdown]
# # Word Frequency Function Comparisons
#
# Summary of the comparison of the two word counting functions:
# **The scikit-learn word counting function is slightly faster and returns fewer non-existent words**
#
# Compare the total word counts of each frequency counter function:

# %%
print("(skl word count, ", "nltk word count)")
sum(word_frequency_counter_skl()['word_frequencies'].values()), sum(word_frequency_counter_nltk()['word_frequencies'].values())
# Out:
# (skl word count,  nltk word count)
# (1986, 2005)

# %% [markdown]
# Compare the speed of each word frequency counter function:

# %%
# %%time
word_frequency_counter_skl()
# Out:
# CPU times: user 222 ms, sys: 321 µs, total: 222 ms
# Wall time: 919 ms
# {'word_frequencies': {'aa': 1,
#   'able': 1,
#   'about': 8,
#   'above': 2,
#   'abroad': 1,
#   'abuses': 2,
#   'access': 2,
#   'accordance': 3,
#   'account': 2,
#   'acting': 1,
#   'activities': 1,
#   'adaptive': 1,
#   'address': 2,
#   'addresses': 4,
#   'adequately': 1,
#   'adjust': 2,
#   'administer': 2,
#   'advanced': 1,
#   'advisors': 1,
#   'affect': 1,
#   'after': 1,
#   'afterwards': 1,
#   'against': 2,
#   'aggregated': 1,
#   'all': 1,
#   'alleged': 1,
#   'allow': 1,
#   'also': 6,
#   'an': 8,
#   'analyse': 1,
#   'analysis': 1,
#   'analytics': 1,
#   'and': 48,
#   'anonymised': 2,
#   'anonymous': 1,
#   'another': 1,
#   'any': 17,
#   'applicable': 6,
#   'application': 2,
#   'approach': 1,
#   'appropriate': 1,
#   'apps': 1,
#   'are': 13,
#   'as': 13,
#   'ask': 1,
#   'asked': 1,
#   'assess': 4,
#   'assist': 1,
#   'associated': 1,
#   'at': 4,
#   'authorities': 1,
#   'authority': 3,
#   'based': 1,
#   'basis': 1,
#   'be': 9,
#   'been': 2,
#   'before': 1,
#   'behalf': 1,
#   'being': 2,
#   'believe': 1,
#   'below': 1,
#   'benefit': 1,
#   'better': 1,
#   'between': 4,
#   'birth': 1,
#   'block': 1,
#   'branches': 1,
#   'broad': 1,
#   'brokers': 1,
#   'business': 4,
#   'but': 1,
#   'by': 14,
#   'cannot': 1,
#   'carriers': 1,
#   'carry': 4,
#   'case': 1,
#   'centre': 1,
#   'certain': 4,
#   'cfc': 4,
#   'cfcunderwriting': 1,
#   'challenges': 1,
#   'change': 1,
#   'changes': 1,
#   'choose': 1,
#   'circumstances': 5,
#   'claim': 4,
#   'clear': 1,
#   'click': 1,
#   'clicking': 1,
#   'collaboration': 1,
#   'collect': 11,
#   'collected': 1,
#   'collects': 1,
#   'com': 1,
#   'come': 1,
#   'commissioner': 1,
#   'committed': 1,
#   'companies': 1,
#   'company': 2,
#   'compelled': 1,
#   'compile': 1,
#   'complaint': 5,
#   'complaints': 1,
#   'complete': 1,
#   'compliance': 1,
#   'comply': 3,
#   'computer': 2,
#   'condition': 3,
#   'connection': 1,
#   'consent': 6,
#   'consented': 3,
#   'consultants': 1,
#   'contact': 7,
#   'continue': 2,
#   'continuing': 1,
#   'continuity': 1,
#   'contract': 7,
#   'contractual': 1,
#   'controller': 1,
#   'cookie': 1,
#   'cookies': 7,
#   'copies': 2,
#   'copy': 1,
#   'countries': 1,
#   'course': 1,
#   'criminal': 2,
#   'customer': 2,
#   'customers': 3,
#   'data': 47,
#   'databases': 2,
#   'date': 1,
#   'delete': 1,
#   'deliver': 1,
#   'details': 1,
#   'detect': 1,
#   'detecting': 1,
#   'directly': 2,
#   'disclose': 2,
#   'disclosure': 3,
#   'dissolution': 1,
#   'do': 6,
#   'doing': 2,
#   'don': 1,
#   'dpo': 1,
#   'duration': 1,
#   'duty': 1,
#   'each': 1,
#   'ec': 1,
#   'efficiently': 1,
#   'email': 1,
#   'employees': 2,
#   'enable': 1,
#   'encourage': 1,
#   'engaging': 1,
#   'engine': 1,
#   'ensure': 2,
#   'entering': 1,
#   'entity': 1,
#   'erase': 2,
#   'erasure': 1,
#   'essential': 1,
#   'estimate': 1,
#   'european': 1,
#   'event': 1,
#   'example': 6,
#   'except': 1,
#   'extent': 1,
#   'facilitate': 2,
#   'family': 2,
#   'features': 1,
#   'fee': 1,
#   'feedback': 1,
#   'feel': 1,
#   'files': 1,
#   'financing': 1,
#   'floor': 1,
#   'following': 2,
#   'follows': 1,
#   'for': 36,
#   'form': 3,
#   'fraud': 2,
#   'from': 7,
#   'fulfil': 1,
#   'fundamental': 1,
#   'further': 2,
#   'geographic': 1,
#   'get': 1,
#   'give': 1,
#   'google': 4,
#   'gracechurch': 1,
#   'ground': 2,
#   'grounds': 3,
#   'group': 1,
#   'has': 1,
#   'have': 14,
#   'headquartered': 1,
#   'health': 3,
#   'help': 3,
#   'here': 2,
#   'hold': 3,
#   'holding': 1,
#   'how': 3,
#   'however': 2,
#   'ico': 1,
#   'identifiable': 1,
#   'identified': 1,
#   'identifies': 1,
#   'identity': 3,
#   'if': 9,
#   'improve': 3,
#   'in': 29,
#   'inaccurate': 1,
#   'include': 3,
#   'included': 1,
#   'including': 4,
#   'incomplete': 1,
#   'indirectly': 1,
#   'individuals': 2,
#   'information': 33,
#   'instructions': 1,
#   'insurance': 12,
#   'integrity': 1,
#   'interest': 2,
#   'interests': 3,
#   'international': 1,
#   'internet': 2,
#   'investigate': 1,
#   'investigation': 1,
#   'invite': 1,
#   'ip': 4,
#   'is': 12,
#   'it': 2,
#   'its': 1,
#   'joint': 1,
#   'keep': 3,
#   'keeping': 2,
#   'kingdom': 1,
#   'law': 9,
#   'lawful': 3,
#   'lawfully': 1,
#   'lawfulness': 1,
#   'legal': 9,
#   'legitimate': 4,
#   'like': 1,
#   'limited': 1,
#   'limits': 1,
#   'link': 1,
#   'linked': 2,
#   'listed': 1,
#   'litigate': 1,
#   'located': 1,
#   'lodge': 2,
#   'log': 1,
#   'london': 1,
#   'longer': 1,
#   'made': 2,
#   'make': 9,
#   'malicious': 1,
#   'manage': 1,
#   'market': 1,
#   'marketing': 4,
#   'may': 30,
#   'means': 1,
#   'members': 2,
#   'mental': 3,
#   'merger': 2,
#   'might': 2,
#   'mobile': 1,
#   'more': 5,
#   'movement': 1,
#   'names': 1,
#   'navigate': 1,
#   'navigation': 1,
#   'necessary': 1,
#   'need': 5,
#   'needs': 1,
#   'new': 1,
#   'no': 1,
#   'non': 5,
#   'not': 6,
#   'note': 2,
#   'number': 2,
#   'numerous': 1,
#   'object': 2,
#   'obligation': 2,
#   'obligations': 5,
#   'obtain': 1,
#   'of': 53,
#   'offence': 2,
#   'offer': 1,
#   'office': 1,
#   'officer': 3,
#   'offices': 1,
#   'on': 10,
#   'one': 8,
#   'online': 4,
#   'only': 3,
#   'optimise': 1,
#   'optional': 1,
#   'optout': 1,
#   'or': 51,
#   'order': 4,
#   'organisation': 1,
#   'other': 5,
#   'our': 54,
#   'ours': 1,
#   'out': 6,
#   'outside': 1,
#   'outsourced': 2,
#   'override': 1,
#   'overriding': 1,
#   'own': 2,
#   'owners': 1,
#   'page': 4,
#   'pages': 1,
#   'paragraph': 1,
#   'part': 1,
#   'participate': 1,
#   'participation': 1,
#   'particular': 2,
#   'parties': 2,
#   'partners': 1,
#   'parts': 2,
#   'party': 3,
#   'password': 1,
#   'period': 1,
#   'permanent': 1,
#   'permanently': 1,
#   'permitted': 3,
#   'personal': 37,
#   'personalised': 1,
#   'personally': 1,
#   'physical': 3,
#   'place': 5,
#   'placed': 1,
#   'please': 6,
#   'policies': 1,
#   'policy': 7,
#   'portals': 1,
#   'prevent': 1,
#   'preventing': 1,
#   'previous': 1,
#   'previously': 1,
#   'primary': 1,
#   'prior': 1,
#   'privacy': 6,
#   'process': 6,
#   'processed': 1,
#   'processing': 10,
#   'products': 9,
#   'program': 1,
#   'proof': 1,
#   'protect': 2,
#   'protected': 1,
#   'protection': 6,
#   'protocol': 1,
#   'provide': 8,
#   'provided': 3,
#   'provider': 2,
#   'providers': 3,
#   'provides': 1,
#   'providing': 1,
#   'provision': 2,
#   'public': 2,
#   'purpose': 1,
#   'purposes': 11,
#   'put': 1,
#   'questions': 2,
#   'quote': 2,
#   'reason': 1,
#   'reasonable': 1,
#   'reasons': 1,
#   'recaptcha': 3,
#   'recognise': 1,
#   'rectification': 1,
#   'rectify': 2,
#   'refer': 1,
#   'referred': 1,
#   'register': 1,
#   'registered': 1,
#   'regulatory': 1,
#   'reinsurers': 1,
#   'related': 1,
#   'relating': 3,
#   'relation': 1,
#   'relevant': 2,
#   'rely': 2,
#   'reorganisation': 1,
#   'reports': 1,
#   'request': 8,
#   'requesting': 1,
#   'required': 4,
#   'research': 1,
#   'reset': 1,
#   'respond': 3,
#   'restrict': 1,
#   'retention': 2,
#   'review': 1,
#   'right': 9,
#   'rights': 5,
#   'risk': 1,
#   'safe': 1,
#   'safeguards': 1,
#   'sale': 2,
#   'same': 1,
#   'sar': 3,
#   'scenarios': 1,
#   'second': 1,
#   'sections': 1,
#   'security': 2,
#   'sensitive': 2,
#   'service': 5,
#   'services': 10,
#   'session': 3,
#   'set': 1,
#   'sets': 1,
#   'share': 1,
#   'should': 1,
#   'similar': 1,
#   'site': 5,
#   'small': 1,
#   'so': 7,
#   'software': 1,
#   'specifically': 1,
#   'statistical': 1,
#   'steps': 1,
#   'stop': 2,
#   'street': 1,
#   'subject': 5,
#   'submit': 1,
#   'subsidiaries': 2,
#   'successor': 1,
#   'such': 6,
#   'sufficiently': 1,
#   'suggest': 1,
#   'supervisory': 2,
#   'suppliers': 1,
#   'survey': 1,
#   'surveys': 2,
#   'systems': 1,
#   'take': 2,
#   'technical': 1,
#   'temporary': 1,
#   'text': 1,
#   'that': 18,
#   'the': 59,
#   'their': 3,
#   'then': 1,
#   'there': 4,
#   'these': 7,
#   'they': 4,
#   'third': 5,
#   'this': 9,
#   'through': 4,
#   'throughout': 1,
#   'time': 7,
#   'to': 111,
#   'together': 1,
#   'track': 1,
#   'transfer': 2,
#   'transferred': 2,
#   'transport': 1,
#   'typeform': 1,
#   'types': 2,
#   'uk': 1,
#   'under': 3,
#   'underwriting': 4,
#   'union': 1,
#   'unique': 1,
#   'united': 1,
#   'unless': 1,
#   'us': 23,
#   'use': 10,
#   'used': 3,
#   'users': 3,
#   'uses': 2,
#   'using': 5,
#   'valid': 2,
#   'venture': 1,
#   'verification': 2,
#   'verify': 1,
#   'visit': 4,
#   'visitor': 2,
#   'visitors': 4,
#   'we': 44,
#   'webhosting': 1,
#   'website': 18,
#   'websites': 5,
#   'well': 1,
#   'what': 1,
#   'when': 3,
#   'where': 11,
#   'which': 12,
#   'who': 1,
#   'whose': 1,
#   'widely': 1,
#   'will': 11,
#   'wish': 2,
#   'with': 18,
#   'withdraw': 3,
#   'withdrawal': 1,
#   'within': 2,
#   'without': 1,
#   'work': 2,
#   'works': 1,
#   'would': 1,
#   'writing': 1,
#   'you': 59,
#   'your': 56}}

# %%
# %%time
word_frequency_counter_nltk()
# Out:
# CPU times: user 368 ms, sys: 0 ns, total: 368 ms
# Wall time: 984 ms
# {'word_frequencies': {'our': 54,
#   'approach': 1,
#   'this': 9,
#   'privacy': 6,
#   'policy': 7,
#   'the': 59,
#   'sets': 1,
#   'out': 6,
#   'how': 3,
#   'we': 44,
#   'cfc': 4,
#   'underwriting': 4,
#   'limited': 1,
#   'registered': 1,
#   'company': 2,
#   'number': 2,
#   'headquartered': 1,
#   'at': 4,
#   'second': 1,
#   'floor': 1,
#   'gracechurch': 1,
#   'street': 1,
#   'london': 1,
#   'ec': 1,
#   'v': 1,
#   'aa': 1,
#   'and': 46,
#   'any': 17,
#   'of': 53,
#   'subsidiaries': 2,
#   'or': 49,
#   'holding': 1,
#   'companies': 1,
#   'together': 1,
#   'referred': 1,
#   'to': 111,
#   'as': 13,
#   'process': 6,
#   'personal': 32,
#   'data': 47,
#   'customers': 3,
#   'brokers': 1,
#   'website': 18,
#   'visitors': 4,
#   'in': 29,
#   'european': 1,
#   'union': 1,
#   'users': 3,
#   'if': 9,
#   'you': 59,
#   'have': 14,
#   'questions': 2,
#   'about': 8,
#   'please': 6,
#   'contact': 7,
#   'protection': 6,
#   'officer': 3,
#   'dpo': 1,
#   'by': 14,
#   'clicking': 1,
#   'here': 2,
#   'what': 1,
#   'information': 33,
#   'do': 6,
#   'collect': 11,
#   'will': 11,
#   'when': 3,
#   'obtain': 1,
#   'a': 29,
#   'quote': 2,
#   'for': 36,
#   'one': 8,
#   'products': 9,
#   'services': 10,
#   'course': 1,
#   'providing': 1,
#   'with': 18,
#   'also': 6,
#   'register': 1,
#   'us': 23,
#   'provide': 8,
#   'your': 56,
#   'through': 4,
#   'types': 2,
#   'may': 30,
#   'include': 3,
#   'insurance': 12,
#   'application': 2,
#   'including': 4,
#   'names': 1,
#   'addresses': 4,
#   'date': 1,
#   'birth': 1,
#   'other': 5,
#   'provided': 3,
#   'help': 3,
#   'carry': 4,
#   'obligations': 5,
#   'under': 3,
#   'contract': 7,
#   'place': 5,
#   'between': 4,
#   'relating': 3,
#   'an': 8,
#   'claim': 4,
#   'make': 9,
#   'mobile': 1,
#   'apps': 1,
#   'customer': 2,
#   'portals': 1,
#   'use': 10,
#   'share': 1,
#   'third': 5,
#   'parties': 2,
#   'acting': 1,
#   'on': 10,
#   'behalf': 1,
#   'more': 5,
#   'following': 2,
#   'purposes': 11,
#   'analyse': 1,
#   'needs': 1,
#   'give': 1,
#   'estimate': 1,
#   'policies': 1,
#   'administer': 2,
#   'assess': 4,
#   'adjust': 2,
#   'respond': 3,
#   'complaint': 5,
#   'might': 2,
#   'ensure': 2,
#   'security': 2,
#   'account': 2,
#   'business': 4,
#   'preventing': 1,
#   'detecting': 1,
#   'fraud': 2,
#   'abuses': 2,
#   'example': 6,
#   'requesting': 1,
#   'verification': 2,
#   'order': 4,
#   'reset': 1,
#   'password': 1,
#   'certain': 4,
#   'circumstances': 5,
#   'need': 5,
#   'sensitive': 2,
#   'which': 12,
#   'physical': 3,
#   'mental': 3,
#   'health': 3,
#   'condition': 3,
#   'members': 2,
#   'family': 2,
#   'employees': 2,
#   'criminal': 2,
#   'offence': 2,
#   'alleged': 1,
#   'committed': 1,
#   'only': 3,
#   'such': 6,
#   'that': 18,
#   'has': 1,
#   'been': 2,
#   'sufficiently': 1,
#   'anonymised': 2,
#   'aggregated': 1,
#   'can': 1,
#   'not': 7,
#   'be': 9,
#   'identified': 1,
#   'directly': 2,
#   'indirectly': 1,
#   'from': 7,
#   'it': 2,
#   'further': 2,
#   'is': 12,
#   'included': 1,
#   'paragraph': 1,
#   'below': 1,
#   'marketing': 4,
#   'where': 11,
#   'consented': 3,
#   'using': 5,
#   'follows': 1,
#   'request': 8,
#   'feel': 1,
#   'interest': 2,
#   'market': 1,
#   'research': 1,
#   'ask': 1,
#   'feedback': 1,
#   'time': 7,
#   'after': 1,
#   'wish': 2,
#   'stop': 2,
#   'these': 7,
#   'email': 1,
#   'optout': 1,
#   'grounds': 3,
#   'processing': 10,
#   'lawfully': 1,
#   'rely': 2,
#   'valid': 2,
#   'legal': 9,
#   'primary': 1,
#   'ground': 2,
#   'fulfil': 1,
#   'take': 2,
#   'steps': 1,
#   'prior': 1,
#   'entering': 1,
#   'however': 2,
#   'there': 4,
#   'consent': 6,
#   'particular': 2,
#   'activities': 1,
#   'legitimate': 4,
#   'interests': 3,
#   'except': 1,
#   'fundamental': 1,
#   'rights': 5,
#   'override': 1,
#   'within': 2,
#   'prevent': 1,
#   'detect': 1,
#   'compliance': 1,
#   'obligation': 2,
#   'subject': 5,
#   'regulatory': 1,
#   'duty': 1,
#   'investigate': 1,
#   'complaints': 1,
#   'made': 2,
#   'against': 2,
#   'part': 1,
#   'investigation': 1,
#   'disclosure': 3,
#   'are': 13,
#   'disclose': 2,
#   'compelled': 1,
#   'accordance': 3,
#   'applicable': 6,
#   'law': 9,
#   'listed': 1,
#   'above': 2,
#   'scenarios': 1,
#   'branches': 1,
#   'associated': 1,
#   'offices': 1,
#   'outsourced': 2,
#   'service': 5,
#   'providers': 3,
#   'suppliers': 1,
#   'facilitate': 2,
#   'provision': 2,
#   'centre': 1,
#   'provider': 2,
#   'safe': 1,
#   'keeping': 2,
#   'webhosting': 1,
#   'collected': 1,
#   'identity': 3,
#   'partners': 1,
#   'verify': 1,
#   'public': 2,
#   'databases': 2,
#   'party': 3,
#   'consultants': 1,
#   'protect': 2,
#   'integrity': 1,
#   'systems': 1,
#   'continuity': 1,
#   'reasons': 1,
#   'carriers': 1,
#   'reinsurers': 1,
#   'another': 1,
#   'entity': 1,
#   'temporary': 1,
#   'permanent': 1,
#   'basis': 1,
#   'joint': 1,
#   'venture': 1,
#   'collaboration': 1,
#   'financing': 1,
#   'sale': 2,
#   'merger': 2,
#   'reorganisation': 1,
#   'change': 1,
#   'form': 3,
#   'dissolution': 1,
#   'similar': 1,
#   'event': 1,
#   'case': 1,
#   'permanently': 1,
#   'transferred': 2,
#   'successor': 1,
#   'advisors': 1,
#   'who': 1,
#   'manage': 1,
#   'litigate': 1,
#   'authorities': 1,
#   'required': 4,
#   'so': 7,
#   'international': 1,
#   'transfer': 2,
#   'countries': 1,
#   'outside': 1,
#   'uk': 1,
#   'set': 1,
#   'throughout': 1,
#   'group': 1,
#   'located': 1,
#   'abroad': 1,
#   'adequately': 1,
#   'protected': 1,
#   'appropriate': 1,
#   'technical': 1,
#   'organisation': 1,
#   'contractual': 1,
#   'lawful': 3,
#   'means': 1,
#   'copy': 1,
#   'safeguards': 1,
#   'put': 1,
#   'retention': 2,
#   'previously': 1,
#   'ours': 1,
#   'then': 1,
#   'continue': 2,
#   'hold': 3,
#   'purpose': 1,
#   'continuing': 1,
#   'connection': 1,
#   'duration': 1,
#   'reasonable': 1,
#   'period': 1,
#   'afterwards': 1,
#   'keep': 3,
#   'no': 1,
#   'longer': 1,
#   'refer': 1,
#   'statistical': 1,
#   'without': 1,
#   'limits': 1,
#   'extent': 1,
#   'doing': 2,
#   'provides': 1,
#   'individuals': 2,
#   'numerous': 1,
#   'right': 9,
#   'access': 2,
#   'rectify': 2,
#   'erase': 2,
#   'restrict': 1,
#   'transport': 1,
#   'object': 2,
#   'their': 3,
#   'lodge': 2,
#   'relevant': 2,
#   'authority': 3,
#   'they': 4,
#   'believe': 1,
#   'being': 2,
#   'processed': 1,
#   'sar': 3,
#   'controller': 1,
#   'permitted': 3,
#   'copies': 2,
#   'would': 1,
#   'like': 1,
#   'writing': 1,
#   'whose': 1,
#   'details': 1,
#   'should': 1,
#   'clear': 1,
#   'submit': 1,
#   'proof': 1,
#   'fee': 1,
#   'rectification': 1,
#   'inaccurate': 1,
#   'complete': 1,
#   'incomplete': 1,
#   'withdraw': 3,
#   'withdrawal': 1,
#   'affect': 1,
#   'lawfulness': 1,
#   'based': 1,
#   'previous': 1,
#   'note': 2,
#   'able': 1,
#   'benefit': 1,
#   'features': 1,
#   'essential': 1,
#   'erasure': 1,
#   'comply': 3,
#   'unless': 1,
#   'reason': 1,
#   'overriding': 1,
#   'necessary': 1,
#   'supervisory': 2,
#   'suggest': 1,
#   'relation': 1,
#   'commissioner': 1,
#   's': 3,
#   'office': 1,
#   'united': 1,
#   'kingdom': 1,
#   'visit': 4,
#   'ico': 1,
#   'instructions': 1,
#   'internet': 2,
#   'protocol': 1,
#   'ip': 4,
#   'site': 5,
#   'log': 1,
#   'address': 2,
#   'unique': 1,
#   'identifies': 1,
#   'computer': 2,
#   'broad': 1,
#   'geographic': 1,
#   'visitor': 2,
#   'optimise': 1,
#   'link': 1,
#   'personally': 1,
#   'identifiable': 1,
#   'cookies': 7,
#   'small': 1,
#   'text': 1,
#   'files': 1,
#   'placed': 1,
#   'websites': 5,
#   'widely': 1,
#   'used': 3,
#   'works': 1,
#   'work': 2,
#   'efficiently': 1,
#   'well': 1,
#   'owners': 1,
#   'delete': 1,
#   'block': 1,
#   'all': 1,
#   'but': 1,
#   'choose': 1,
#   'parts': 2,
#   'session': 3,
#   'sections': 1,
#   'improve': 3,
#   'assist': 1,
#   'navigation': 1,
#   'deliver': 1,
#   'better': 1,
#   'personalised': 1,
#   'cookie': 1,
#   'specifically': 1,
#   'enable': 1,
#   'track': 1,
#   'movement': 1,
#   'page': 4,
#   'don': 1,
#   't': 1,
#   'get': 1,
#   'asked': 1,
#   'same': 1,
#   'each': 1,
#   'navigate': 1,
#   'new': 1,
#   'allow': 1,
#   'recognise': 1,
#   'changes': 1,
#   'google': 4,
#   'analytics': 1,
#   'compile': 1,
#   'reports': 1,
#   'anonymous': 1,
#   'come': 1,
#   'pages': 1,
#   'click': 1,
#   'recaptcha': 3,
#   'uses': 2,
#   'collects': 1,
#   'advanced': 1,
#   'risk': 1,
#   'analysis': 1,
#   'engine': 1,
#   'adaptive': 1,
#   'challenges': 1,
#   'malicious': 1,
#   'software': 1,
#   'engaging': 1,
#   'program': 1,
#   'its': 1,
#   'own': 2,
#   'encourage': 1,
#   'review': 1,
#   'before': 1,
#   'online': 4,
#   'surveys': 2,
#   'invite': 1,
#   'participate': 1,
#   'survey': 1,
#   'related': 1,
#   'participation': 1,
#   'optional': 1,
#   'offer': 1,
#   'typeform': 1,
#   'linked': 2}}
